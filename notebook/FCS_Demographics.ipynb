# %% [markdown]
# # Import, Read CSVs, Concat

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
from ipywidgets import interactive

# %%
callcenter2020 = pd.read_csv("../data/callcenter2020.csv")
callcenter2020.head()
# Out:
#    Report Info                                         Unnamed: 1 Unnamed: 2  \
# 0       Queue:  AWARE,Community Response,Crisis Eng,Crisis Eng...        NaN
# 1          NaN            Crisis Spanish,Crisis Spanish PRIORITY,        NaN
# 2          NaN     Lifeline,MHART,Pet Loss,REDLINE,Referral Line,        NaN
# 3          NaN                                             SAMHSA        NaN
# 4  Start Date:                                           1/1/2020        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10
# 0        NaN         NaN
# 1        NaN         NaN
# ...

# %%
callcenter2021 = pd.read_csv('../data/callcenter2021.csv')
callcenter2021.head()
# Out:
#    Report Info                                         Unnamed: 1 Unnamed: 2  \
# 0       Queue:  AWARE,Community Response,Crisis Eng,Crisis Eng...        NaN
# 1          NaN            Crisis Spanish,Crisis Spanish PRIORITY,        NaN
# 2          NaN     Lifeline,MHART,Pet Loss,REDLINE,Referral Line,        NaN
# 3          NaN                                             SAMHSA        NaN
# 4  Start Date:                                           1/1/2021        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10
# 0        NaN         NaN
# 1        NaN         NaN
# ...

# %%
callcenter2022 = pd.read_csv('../data/callcenter2022.csv')
callcenter2022.head()
# Out:
#     Unnamed: 0 Lifeline,MHART,Pet Loss,REDLINE,Referral Line, Unnamed: 2  \
# 0          NaN                                         SAMHSA        NaN
# 1  Start Date:                                       1/1/2022        NaN
# 2    End Date:                                      4/30/2022        NaN
# 3  Hour range:                                  00:00 - 23:59        NaN
# 4      Period:                                       120 days        NaN
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN        NaN        NaN        NaN
# 4        NaN        NaN        NaN        NaN        NaN        NaN
#
#   Unnamed: 9 Unnamed: 10
# 0        NaN         NaN
# 1        NaN         NaN
# 2        NaN         NaN
# ...

# %%
crisis1 = pd.read_csv('../data/NSSCrisis1.csv', skiprows=2)
crisis1.head()
# Out:
# C:\Users\cbrown\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (17,23,27,28,29,35,54,66,68,69,70,72,80,82,85,88,105,106,107,108,128,140,143,145,146,148,152,153,154,155,157,158,159,160,161,162,163,164,165,168,169,170,171,172,181,182,183,184,185,186,188,189,190,191,192,194,195,196,197,198,200,201,204,205,263,265,266,273,281,286,287,288,303,310,311) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    CallReportNum ReportVersion LinkedToCallReportNum CallDateAndTimeStart  \
# 0       96627022        Crisis                   NaN     12/31/2021 23:35
# 1       96626934        Crisis                   NaN     12/31/2021 23:29
# 2       96626654        Crisis                   NaN     12/31/2021 23:07
# 3       96626370        Crisis                   NaN     12/31/2021 22:45
# 4       96625909        Crisis                   NaN     12/31/2021 22:15
#
# ...

# %%
crisis2 = pd.read_csv('../data/NSSCrisis2.csv', skiprows=2)
crisis2.head()
# Out:
# C:\Users\cbrown\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (26,30,35,38,61,62,63,65,66,67,68,69,72,73,78,92,111,126,127,139,149,150,151,152,153,154,156,157,158,159,160,162,163,164,165,166,168,170,171,172,173,176,215,235,236,240,241,242) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    CallReportNum ReportVersion LinkedToCallReportNum CallDateAndTimeStart  \
# 0    101384892.0    Crisis v.2                   NaN      4/30/2022 23:19
# 1    101384348.0    Crisis v.2                   NaN      4/30/2022 22:46
# 2    101383635.0    Crisis v.2                   NaN      4/30/2022 22:03
# 3    101383441.0    Crisis v.2                   NaN      4/30/2022 21:52
# 4    101383414.0    Crisis v.2                   NaN      4/30/2022 21:50
#
#   CallDateAndTimeEnd  CallLength  CallerNum  PhoneWorkerNum  PhoneWorkerName  \
# ...

# %%
crisis = pd.concat([crisis2, crisis1])
crisis.head()
# Out:
#    CallReportNum ReportVersion LinkedToCallReportNum CallDateAndTimeStart  \
# 0    101384892.0    Crisis v.2                   NaN      4/30/2022 23:19
# 1    101384348.0    Crisis v.2                   NaN      4/30/2022 22:46
# 2    101383635.0    Crisis v.2                   NaN      4/30/2022 22:03
# 3    101383441.0    Crisis v.2                   NaN      4/30/2022 21:52
# 4    101383414.0    Crisis v.2                   NaN      4/30/2022 21:50
#
#   CallDateAndTimeEnd  CallLength  CallerNum  PhoneWorkerNum  PhoneWorkerName  \
# 0    4/30/2022 23:27         8.0  1025380.0         55599.0  Darren Anderson
# 1    4/30/2022 23:13        27.0       -1.0         55599.0  Darren Anderson
# 2    4/30/2022 22:27        24.0       -1.0        169061.0   Tandra Freeman
# 3    4/30/2022 22:15        23.0       -1.0        170047.0       Jane Davis
# 4    4/30/2022 21:51         1.0       -1.0        169061.0   Tandra Freeman
#
#    WasRealCall  ...  \
# 0          NaN  ...
# ...

# %%
#crisis['Call Year'] = crisis.CallDateAndTimeStart.str[5:9]
#print(crisis['Call Year'])
#needs more work since date format does not have consistent number of characters nor does time.
# Out:
# 0        022
# 1        022
# 2        022
# 3        022
# 4        022
#         ...
# 52871    20
# 52872    20
# 52873    20
# 52874    20
# 52875    20
# Name: Call Year, Length: 64524, dtype: object

# %%
#filter2020 = crisis['Call Year'].isin(['2020'])
#filter2020.head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Call Year, dtype: bool

# %%
#calls2020 = crisis[filter2020]
#calls2020.head()
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# # Demographics Deep Dive

# %%
#code from Abigail
demographics = crisis.loc[:,['Demographics' in i for i in crisis.columns]]
demographics.head()
# Out:
#   HOM AX Demographics - Occupation SUI AX Demographics - Name of Third Party  \
# 0                              NaN                                       NaN
# 1                              NaN                                       NaN
# 2                              NaN                                       NaN
# 3                              NaN                                       NaN
# 4                              NaN                                       NaN
#
#    SUI AX Demographics - Occupation CRISIS Demographics - Age  \
# 0                               NaN                     56-70
# 1                               NaN                       NaN
# 2                               NaN                       NaN
# 3                               NaN                       NaN
# 4                               NaN                       NaN
#
#   CRISIS Demographics - Gender Identity CRISIS Demographics - Military  \
# ...

# %% [markdown]
# ## Count of Filled Demographics Cells

# %%
demographics.count()
# Out:
# HOM AX Demographics - Occupation                                                                                                                         2
# SUI AX Demographics - Name of Third Party                                                                                                                5
# SUI AX Demographics - Occupation                                                                                                                         0
# CRISIS Demographics - Age                                                                                                                            22061
# CRISIS Demographics - Gender Identity                                                                                                                41820
# CRISIS Demographics - Military                                                                                                                       54543
# ...

# %% [markdown]
# ## Count of Null Demographics Cells

# %%
demographics.isnull().sum()
# Out:
# HOM AX Demographics - Occupation                                                                                                                     64522
# SUI AX Demographics - Name of Third Party                                                                                                            64519
# SUI AX Demographics - Occupation                                                                                                                     64524
# CRISIS Demographics - Age                                                                                                                            42463
# CRISIS Demographics - Gender Identity                                                                                                                22704
# CRISIS Demographics - Military                                                                                                                        9981
# ...

# %% [markdown]
# ### Occupation

# %%
crisis['CRISIS Demographics - Occupation'].value_counts(normalize=True)
# Out:
# Works at Goodwill                     0.296329
# News Anchor                           0.187556
# Construction Worker                   0.146374
# bagger at Kroger                      0.085497
# Substitute Teacher                    0.074754
#                                         ...
# Factory worker                        0.000448
# Sergeant                              0.000448
# Retired nondenominational preacher    0.000448
# Unemployed                            0.000448
# Caregiver at a Nursing Home           0.000448
# Name: CRISIS Demographics - Occupation, Length: 89, dtype: float64

# %%
crisis['CRISIS Demographics - Occupation'].value_counts()
# Out:
# Works at Goodwill                     662
# News Anchor                           419
# Construction Worker                   327
# bagger at Kroger                      191
# Substitute Teacher                    167
#                                      ...
# Factory worker                          1
# Sergeant                                1
# Retired nondenominational preacher      1
# Unemployed                              1
# Caregiver at a Nursing Home             1
# Name: CRISIS Demographics - Occupation, Length: 89, dtype: int64

# %%
crisis.groupby('CRISIS Demographics - Education Level')['CRISIS Demographics - Occupation'].value_counts()
# Out:
# CRISIS Demographics - Education Level  CRISIS Demographics - Occupation
# College graduate                       Nurse                                   5
#                                        Teacher                                 3
#                                        Educator                                2
#                                        Biotech lab worker                      1
#                                        Electrician                             1
#                                        News broadcaster                        1
#                                        Top Model/Actress/Fashion Industry      1
#                                        journalist                              1
#                                        nurse                                   1
#                                        student                                 1
#                                        teacher                                 1
# ...

# %%
goodwill = crisis.loc[crisis['CRISIS Demographics - Occupation'] == 'Works at Goodwill']
goodwill.head(10)
# Out:
#      CallReportNum ReportVersion LinkedToCallReportNum CallDateAndTimeStart  \
# 102     96585245.0        Crisis                   NaN     12/30/2021 15:50
# 141     96563106.0        Crisis                   NaN      12/30/2021 8:05
# 213     96520507.0        Crisis                   NaN      12/29/2021 5:59
# 281     96492292.0        Crisis                   NaN     12/28/2021 13:15
# 291     96486971.0        Crisis                   NaN     12/28/2021 11:42
# 292     96485767.0        Crisis                   NaN     12/28/2021 11:19
# 346     96470082.0        Crisis                   NaN     12/27/2021 22:10
# 407     96436609.0        Crisis                   NaN      12/27/2021 8:01
# 411     96434973.0        Crisis                   NaN      12/27/2021 6:28
# 423     96432824.0        Crisis                   NaN      12/27/2021 2:17
#
#     CallDateAndTimeEnd  CallLength  CallerNum  PhoneWorkerNum  \
# 102   12/30/2021 15:51         1.0  3048547.0        166157.0
# ...

# %%
goodwill['CallerNum'].value_counts()
#Does this mean its the same caller?
# Out:
# 3048547.0    662
# Name: CallerNum, dtype: int64

# %%
top5occ = crisis.loc[crisis['CRISIS Demographics - Occupation'].isin(['Works at Goodwill', 'News Anchor', 'Construction Worker', 'bagger at Kroger', 'Substitute Teacher'])]
top5occ.head(10)
# Out:
#      CallReportNum ReportVersion LinkedToCallReportNum CallDateAndTimeStart  \
# 29      96614528.0        Crisis                   NaN     12/31/2021 14:04
# 55      96602679.0        Crisis                   NaN      12/31/2021 7:23
# 59      96600111.0        Crisis                   NaN      12/31/2021 3:06
# 102     96585245.0        Crisis                   NaN     12/30/2021 15:50
# 127     96569238.0        Crisis                   NaN     12/30/2021 10:38
# 141     96563106.0        Crisis                   NaN      12/30/2021 8:05
# 143     96561950.0        Crisis                   NaN      12/30/2021 7:13
# 194     96533383.0        Crisis                   NaN     12/29/2021 12:44
# 213     96520507.0        Crisis                   NaN      12/29/2021 5:59
# 214     96518089.0        Crisis                   NaN      12/29/2021 5:55
#
#     CallDateAndTimeEnd  CallLength  CallerNum  PhoneWorkerNum  \
# 29    12/31/2021 14:15        11.0  4309507.0        136748.0
# ...

# %%
top5occ['CallerNum'].value_counts()
#Again, are we looking at a singular caller for each top occupation?
# Out:
# 3048547.0    662
# 3769693.0    419
# 3425890.0    327
# 1033159.0    191
# 4309507.0    167
# Name: CallerNum, dtype: int64

# %%
crisis['CallerNum'].value_counts()
# Out:
# -1.0          45854
#  1155260.0     1392
#  2270935.0     1156
#  1033478.0     1118
#  3620809.0      926
#               ...
#  1814485.0        1
#  3829343.0        1
#  2479367.0        1
#  5229213.0        1
#  4645238.0        1
# Name: CallerNum, Length: 63, dtype: int64

# %%
crisis.groupby('CallerNum')['CRISIS Demographics - Occupation'].value_counts()
# Out:
# CallerNum   CRISIS Demographics - Occupation
# -1.0        Nurse                                15
#             Student                               8
#             student                               7
#             Retired                               4
#             Teacher                               4
#                                                ...
#  3425890.0  Construction Worker                 327
#  3769693.0  News Anchor                         419
#             FedEx Driver                          6
#             Former News Anchor                    1
#  4309507.0  Substitute Teacher                  167
# Name: CRISIS Demographics - Occupation, Length: 91, dtype: int64

# %%
top5occ['CRISIS Call Information - Call Type'].value_counts(normalize=True)
# Out:
# Crisis                                     0.947905
# Hang-up                                    0.042469
# Dropped Call (Due to technical reasons)    0.003964
# Outbound                                   0.003964
# Information                                0.001133
# Prank Call                                 0.000566
# Name: CRISIS Call Information - Call Type, dtype: float64

# %%
top5occ['CRISIS Call Information - Call Type'].value_counts()
# Out:
# Crisis                                     1674
# Hang-up                                      75
# Dropped Call (Due to technical reasons)       7
# Outbound                                      7
# Information                                   2
# Prank Call                                    1
# Name: CRISIS Call Information - Call Type, dtype: int64

# %%
top5occ['CRISIS Demographics - Age'].value_counts()
# Out:
# 56-70    989
# 25-30    584
# 41-55    191
# 18-24      2
# Name: CRISIS Demographics - Age, dtype: int64

# %%
top5occ['CRISIS Demographics - Age'].value_counts(normalize=True)
# Out:
# 56-70    0.560023
# 25-30    0.330691
# 41-55    0.108154
# 18-24    0.001133
# Name: CRISIS Demographics - Age, dtype: float64

# %%
top5occ['CallLength'].describe()
# Out:
# count    1766.000000
# mean        9.334655
# std         6.458901
# min         1.000000
# 25%         4.000000
# 50%        10.000000
# 75%        12.000000
# max        72.000000
# Name: CallLength, dtype: float64

# %%
top5occ.groupby('CRISIS Demographics - Age')['CRISIS Demographics - Occupation'].value_counts()
# Out:
# CRISIS Demographics - Age  CRISIS Demographics - Occupation
# 18-24                      News Anchor                           2
# 25-30                      News Anchor                         417
#                            Substitute Teacher                  167
# 41-55                      bagger at Kroger                    191
# 56-70                      Works at Goodwill                   662
#                            Construction Worker                 327
# Name: CRISIS Demographics - Occupation, dtype: int64

# %%
top5occ.groupby('CRISIS Demographics - Has a disability?')['CRISIS Demographics - Occupation'].value_counts()
# Out:
# CRISIS Demographics - Has a disability?  CRISIS Demographics - Occupation
# No                                       bagger at Kroger                    191
# Yes                                      Works at Goodwill                   662
#                                          News Anchor                           1
# Name: CRISIS Demographics - Occupation, dtype: int64

# %%
top5occ.groupby('CRISIS Demographics - Ethnicity')['CRISIS Demographics - Occupation'].value_counts()
# Out:
# CRISIS Demographics - Ethnicity  CRISIS Demographics - Occupation
# African-American                 News Anchor                         419
#                                  Substitute Teacher                  167
# Caucasian                        Construction Worker                 327
#                                  bagger at Kroger                    191
#                                  Works at Goodwill                     4
# Name: CRISIS Demographics - Occupation, dtype: int64

# %%
goodwill['CallLength'].value_counts(normalize=True)
# Out:
# 1.0     0.163142
# 2.0     0.116314
# 3.0     0.113293
# 10.0    0.092145
# 4.0     0.083082
# 5.0     0.063444
# 7.0     0.055891
# 8.0     0.051360
# 9.0     0.051360
# 11.0    0.046828
# 6.0     0.045317
# 15.0    0.033233
# 12.0    0.028701
# 13.0    0.024169
# 14.0    0.015106
# 16.0    0.009063
# 20.0    0.001511
# 23.0    0.001511
# 19.0    0.001511
# 30.0    0.001511
# 18.0    0.001511
# Name: CallLength, dtype: float64

# %%
top5occ['CallLength'].value_counts(normalize=True)
# Out:
# 10.0    0.182333
# 1.0     0.101925
# 11.0    0.075878
# 15.0    0.069649
# 12.0    0.065119
# 9.0     0.062854
# 2.0     0.057758
# 3.0     0.051529
# 4.0     0.039638
# 7.0     0.039071
# 8.0     0.037939
# 5.0     0.033975
# 6.0     0.033409
# 13.0    0.030011
# 16.0    0.026048
# 14.0    0.021518
# 18.0    0.013590
# 17.0    0.011891
# 19.0    0.007361
# 20.0    0.006795
# 21.0    0.005096
# 23.0    0.003398
# 24.0    0.002265
# 22.0    0.001699
# 27.0    0.001699
# 37.0    0.001699
# 30.0    0.001699
# 25.0    0.001699
# 26.0    0.001699
# 40.0    0.001133
# 29.0    0.001133
# 36.0    0.001133
# 33.0    0.001133
# 45.0    0.000566
# 66.0    0.000566
# 31.0    0.000566
# 65.0    0.000566
# 72.0    0.000566
# 35.0    0.000566
# 44.0    0.000566
# 50.0    0.000566
# 41.0    0.000566
# 47.0    0.000566
# 28.0    0.000566
# Name: CallLength, dtype: float64

# %% [markdown]
# ### Education

# %%
crisis['CRISIS Demographics - Education Level'].value_counts()
# Out:
# High school diploma/GED     2427
# Some college                1799
# Masters/PhD graduate        1175
# College graduate             986
# Some high school             101
# Some graduate level work      17
# No schooling completed         2
# Name: CRISIS Demographics - Education Level, dtype: int64

# %%
crisis['CRISIS Demographics - Education Level'].value_counts(normalize=True)
# Out:
# High school diploma/GED     0.372983
# Some college                0.276471
# Masters/PhD graduate        0.180575
# College graduate            0.151529
# Some high school            0.015522
# Some graduate level work    0.002613
# No schooling completed      0.000307
# Name: CRISIS Demographics - Education Level, dtype: float64

# %%
top5occ.groupby('CRISIS Demographics - Education Level')['CallLength'].value_counts()
# Out:
# CRISIS Demographics - Education Level  CallLength
# High school diploma/GED                1.0           108
#                                        2.0            77
#                                        3.0            75
#                                        10.0           61
#                                        4.0            55
#                                                     ...
# Some college                           17.0            1
#                                        20.0            1
#                                        22.0            1
#                                        27.0            1
#                                        33.0            1
# Name: CallLength, Length: 76, dtype: int64

# %%
crisis.groupby('CRISIS Demographics - Education Level')['CallLength'].value_counts()
# Out:
# CRISIS Demographics - Education Level  CallLength
# College graduate                       20.0          245
#                                        21.0          123
#                                        22.0           85
#                                        23.0           60
#                                        24.0           58
#                                                     ...
# Some high school                       48.0            1
#                                        50.0            1
#                                        55.0            1
#                                        58.0            1
#                                        60.0            1
# Name: CallLength, Length: 248, dtype: int64

# %%
hsged = crisis.loc[crisis['CRISIS Demographics - Education Level'] == 'High school diploma/GED']
hsged.head(10)
# Out:
#      CallReportNum ReportVersion LinkedToCallReportNum CallDateAndTimeStart  \
# 12      96623850.0        Crisis                   NaN     12/31/2021 20:10
# 21      96619732.0        Crisis                   NaN     12/31/2021 17:03
# 39      96608424.0        Crisis                   NaN     12/31/2021 11:06
# 42      96607179.0        Crisis                   NaN     12/31/2021 10:27
# 94      96588385.0        Crisis                   NaN     12/30/2021 17:07
# 102     96585245.0        Crisis                   NaN     12/30/2021 15:50
# 131     96567980.0        Crisis                   NaN     12/30/2021 10:12
# 141     96563106.0        Crisis                   NaN      12/30/2021 8:05
# 158     96598712.0        Crisis                   NaN     12/29/2021 23:13
# 164     96553867.0        Crisis                   NaN     12/29/2021 20:49
#
#     CallDateAndTimeEnd  CallLength  CallerNum  PhoneWorkerNum  \
# 12    12/31/2021 20:20        10.0  1802329.0        169061.0
# ...

# %%
hsged['CallLength'].value_counts(normalize=True)
# Out:
# 10.0    0.248867
# 9.0     0.093943
# 11.0    0.086115
# 8.0     0.072105
# 1.0     0.068397
# 7.0     0.057684
# 3.0     0.051092
# 6.0     0.048620
# 12.0    0.046148
# 5.0     0.044087
# 2.0     0.043263
# 4.0     0.037907
# 13.0    0.019365
# 15.0    0.018129
# 14.0    0.016069
# 16.0    0.010301
# 18.0    0.005356
# 20.0    0.004120
# 22.0    0.003296
# 17.0    0.002884
# 23.0    0.002060
# 21.0    0.002060
# 31.0    0.001648
# 19.0    0.001648
# 28.0    0.001236
# 27.0    0.001236
# 25.0    0.001236
# 50.0    0.001236
# 26.0    0.001236
# 53.0    0.000824
# 32.0    0.000824
# 30.0    0.000824
# 29.0    0.000412
# 79.0    0.000412
# 24.0    0.000412
# 73.0    0.000412
# 60.0    0.000412
# 88.0    0.000412
# 33.0    0.000412
# 57.0    0.000412
# 44.0    0.000412
# 46.0    0.000412
# 35.0    0.000412
# 36.0    0.000412
# 38.0    0.000412
# 63.0    0.000412
# 52.0    0.000412
# Name: CallLength, dtype: float64

# %%
collegegrad = crisis.loc[crisis['CRISIS Demographics - Education Level'] == 'College graduate']
collegegrad.head()
# Out:
#      CallReportNum ReportVersion LinkedToCallReportNum CallDateAndTimeStart  \
# 2       96626654.0        Crisis                   NaN     12/31/2021 23:07
# 207     96519818.0        Crisis                   NaN      12/29/2021 7:51
# 221     96516925.0        Crisis                   NaN      12/29/2021 3:43
# 241     96559737.0        Crisis                   NaN     12/28/2021 22:21
# 259     96507276.0        Crisis                   NaN     12/28/2021 18:28
#
#     CallDateAndTimeEnd  CallLength  CallerNum  PhoneWorkerNum  \
# 2     12/31/2021 23:28        21.0  1030262.0        136748.0
# 207    12/29/2021 8:15        24.0  1031947.0        140958.0
# 221    12/29/2021 3:55        12.0  1030262.0        164365.0
# 241   12/28/2021 22:44        23.0       -1.0        116928.0
# 259   12/28/2021 18:48        20.0       -1.0         88564.0
#
#        PhoneWorkerName  WasRealCall  ...  Risk Assessment - Suicidal SLAPs  \
# ...
