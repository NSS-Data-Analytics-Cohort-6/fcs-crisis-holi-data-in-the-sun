# %%
import requests
import matplotlib.pyplot as plt
import json
import pandas as pd

# %%
#pip install openpyxl

# %%
#from openpyxl import load_workbook
#NSScrisis = load_workbook("../data/NSSCrisisv.1 (1).xlsx")

# %%
#NSScrisis

# %%
pd.read_excel('../data/NSSCrisisv.1 (1).xlsx')
# Out:
#       FamilyandChildrensService - CallReports export requested on Monday May 9 2022 at 9:57 AM.  \
# 0
# 1                                          CallReportNum
# 2                                               96627022
# 3                                               96626934
# 4                                               96626654
# ...                                                  ...
# 52873                                           69492892
# 52874                                           69492741
# 52875                                           69492019
# 52876                                           69492070
# 52877                                           69492055
#
#           Unnamed: 1             Unnamed: 2            Unnamed: 3  \
# 0                NaN                    NaN                   NaN
# 1      ReportVersion  LinkedToCallReportNum  CallDateAndTimeStart
# 2             Crisis                    NaN   2021-12-31 23:35:00
# ...

# %%
pd.read_excel('../data/NSSCrisisv.1 (1).xlsx', index_col=0, header=0, usecols="A:J", names="")
# Out:
#                                                        Unnamed: 1  \
# FamilyandChildrensService - CallReports export ...
#                                                               NaN
# CallReportNum                                       ReportVersion
# 96627022                                                   Crisis
# 96626934                                                   Crisis
# 96626654                                                   Crisis
# ...                                                           ...
# 69492892                                                   Crisis
# 69492741                                                   Crisis
# 69492019                                                   Crisis
# 69492070                                                   Crisis
# 69492055                                                   Crisis
#
#                                                                Unnamed: 2  \
# ...

# %%
pd.read_excel('../data/NSSCrisisv.2.xlsx')
# Out:
#       FamilyandChildrensService - CallReports export requested on Monday May 9 2022 at 9:58 AM.  \
# 0
# 1                                          CallReportNum
# 2                                              101384892
# 3                                              101384348
# 4                                              101383635
# ...                                                  ...
# 10645                                           96673255
# 10646                                           96645142
# 10647                                           96640741
# 10648                                           96849680
# 10649                                           97267704
#
#                       Unnamed: 1             Unnamed: 2            Unnamed: 3  \
# 0                            NaN                    NaN                   NaN
# 1                  ReportVersion  LinkedToCallReportNum  CallDateAndTimeStart
# ...

# %%
pd.read_excel('../data/NSSCrisisv.2.xlsx', index_col=0, header=0, usecols="A:G")
# Out:
#                                                                    Unnamed: 1  \
# FamilyandChildrensService - CallReports export ...
#                                                                           NaN
# CallReportNum                                                   ReportVersion
# 101384892                                                          Crisis v.2
# 101384348                                                          Crisis v.2
# 101383635                                                          Crisis v.2
# ...                                                                       ...
# 96673255                                            Homicidal Risk Assessment
# 96645142                                              Suicide Risk Assessment
# 96640741                                              Suicide Risk Assessment
# 96849680                                                           Crisis v.2
# ...

# %%
crisis = pd.concat(['NSScrisis.2', 'NSScrisis.1'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12264/740896993.py in <module>
# ----> 1 crisis = pd.concat(['NSScrisis.2', 'NSScrisis.1'])
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     292     ValueError: Indexes have overlapping values: ['a']
#     293     """
# --> 294     op = _Concatenator(
#     295         objs,
#     296         axis=axis,
#
# ...

# %%
contact1 = pd.read_csv('../data/Contact center call volume_2020-2022.xlsx - 2020.csv')

# %%
contact1
# Out:
#           Report Info                                         Unnamed: 1  \
# 0              Queue:  AWARE,Community Response,Crisis Eng,Crisis Eng...
# 1                 NaN            Crisis Spanish,Crisis Spanish PRIORITY,
# 2                 NaN     Lifeline,MHART,Pet Loss,REDLINE,Referral Line,
# 3                 NaN                                             SAMHSA
# 4         Start Date:                                           1/1/2020
# ..                ...                                                ...
# 99     Within 90 secs                                        11637 calls
# 100   Within 105 secs                                        12062 calls
# 101   Within 120 secs                                        12403 calls
# 102   Within 135 secs                                        12981 calls
# 103  Within 150+ secs                                        16313 calls
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...

# %%
contact2 = pd.read_csv('../data/Contact center call volume_2020-2022.xlsx - 2021.csv')

# %%
contact2
# Out:
#           Report Info                                         Unnamed: 1  \
# 0              Queue:  AWARE,Community Response,Crisis Eng,Crisis Eng...
# 1                 NaN            Crisis Spanish,Crisis Spanish PRIORITY,
# 2                 NaN     Lifeline,MHART,Pet Loss,REDLINE,Referral Line,
# 3                 NaN                                             SAMHSA
# 4         Start Date:                                           1/1/2021
# ..                ...                                                ...
# 112    Within 90 secs                                         9823 calls
# 113   Within 105 secs                                        10303 calls
# 114   Within 120 secs                                        10741 calls
# 115   Within 135 secs                                        11422 calls
# 116  Within 150+ secs                                        16056 calls
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...

# %%
contact3 = pd.read_csv('../data/Contact center call volume_2020-2022.xlsx - 2022.csv')

# %%
contact3
# Out:
#            Unnamed: 0 Lifeline,MHART,Pet Loss,REDLINE,Referral Line,  \
# 0                 NaN                                         SAMHSA
# 1         Start Date:                                       1/1/2022
# 2           End Date:                                      4/30/2022
# 3         Hour range:                                  00:00 - 23:59
# 4             Period:                                       120 days
# ..                ...                                            ...
# 99     Within 90 secs                                     2340 calls
# 100   Within 105 secs                                     2487 calls
# 101   Within 120 secs                                     2596 calls
# 102   Within 135 secs                                     2767 calls
# 103  Within 150+ secs                                     3846 calls
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# ...
